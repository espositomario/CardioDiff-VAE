# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
RNA_TABLE = pd.read_csv('./data/my_RNA_SRA_table.csv')
RNA_TABLE
# Out:
#   run_accession                  SAMPLE_ID TARGET CELL_TYPE  REP  \
# 0     SRR900927  RNA_ESC_1_Wamstad_2013_PE    RNA       ESC    1
# 1     SRR900928  RNA_ESC_2_Wamstad_2013_PE    RNA       ESC    2
# 2     SRR900929  RNA_MES_1_Wamstad_2013_PE    RNA       MES    1
# 3     SRR900930  RNA_MES_2_Wamstad_2013_PE    RNA       MES    2
# 4     SRR900931   RNA_CP_1_Wamstad_2013_PE    RNA        CP    1
# 5     SRR900932   RNA_CP_2_Wamstad_2013_PE    RNA        CP    2
# 6     SRR900933   RNA_CM_1_Wamstad_2013_PE    RNA        CM    1
# 7     SRR900934   RNA_CM_2_Wamstad_2013_PE    RNA        CM    2
#
#            OLD_SAMPLE_ID
# 0   RNA_ESC_Rep_1_JW-H9B
# 1  RNA_ESC_Rep_2_JW-H10B
# 2   RNA_MES_Rep_1_JW-H3B
# 3   RNA_MES_Rep_2_JW-H4B
# 4    RNA_CP_Rep_1_JW-H5B
# 5    RNA_CP_Rep_2_JW-H6B
# 6    RNA_CM_Rep_1_JW-H7B
# 7    RNA_CM_Rep_2_JW-H8B

# %% [markdown]
# ### Download SRA

# %%
import sys
import subprocess 
import shlex
OUTDIR= '/usr/local/molbio/01_raw_data/Wamstad/'
NT = '12'
RANGE=(1,8)

MAPFILES='/usr/local/molbio/02_map_files/mm10/'
SSD_DIR='/Volumes/MariusSSD/prj/crg/02_map_files/mm10/Wamstad/'

# %%
# %%time

for i,row in RNA_TABLE.iterrows():
    if i in range(RANGE[0],RANGE[1]):
        SAMPLE_ID = row['SAMPLE_ID']
        SRA = row['run_accession']
        print(f'\nIndex   = {i}')
        print(f'SRA       = {SRA}')
        print(f'SAMPLE_ID = {SAMPLE_ID}') 
        print(f'OUTDIR    = {OUTDIR}\n')
        ! parallel-fastq-dump --tmpdir . --sra-id {SRA} --threads {NT} --outdir {OUTDIR} --gzip --split-files

# %% [markdown]
# ### Map with TopHat2

# %%
# %%time

for i,row in RNA_TABLE.iterrows():
    if i in range(RANGE[0],RANGE[1]):
        try:
            SRA = row['run_accession']
            SAMPLE_ID = row['SAMPLE_ID']
            FQ1 = OUTDIR+SRA+'_1.fastq.gz'
            FQ2 = OUTDIR+SRA+'_2.fastq.gz'
            print(f'\nIndex     = {i}')
            print(f'SRA       = {SRA}')
            print(f'SAMPLE_ID = {SAMPLE_ID}')
            print(f'FQ_DIR    = {OUTDIR}')
            print(f'FQ1 = {FQ1}')
            print(f'FQ2 = {FQ2}')
            print(f'OUTDIR = {MAPFILES}{SAMPLE_ID}\n')
            #subprocess.run(['pigz', '-d', '-k', '-p','6', FQ1 +'.gz'])
            #subprocess.run(['pigz', '-d', '-k', '-p','6', FQ2 +'.gz'])
            #subprocess.run(shlex.split(f'ProcessRNAseq.pl -v -p mouse mm10 {FQ1} {FQ2} {SAMPLE_ID}'))
            ! ./ProcessRNAseq.pl -v -p mouse mm10 {FQ1} {FQ2} {SAMPLE_ID}
            #subprocess.run(['rm', '-f', FQ1, FQ2])
            ! rsync -avh --remove-source-files {MAPFILES}{SAMPLE_ID} {SSD_DIR}
        except Exception:
            print('Error')
            break
# Out:
# Index     = 1
# SRA       = SRR900928
# SAMPLE_ID = RNA_ESC_2_Wamstad_2013_PE
# FQ_DIR    = /usr/local/molbio/01_raw_data/Wamstad/
# FQ1 = /usr/local/molbio/01_raw_data/Wamstad/SRR900928_1.fastq.gz
# FQ2 = /usr/local/molbio/01_raw_data/Wamstad/SRR900928_2.fastq.gz
# OUTDIR = /usr/local/molbio/02_map_files/mm10/RNA_ESC_2_Wamstad_2013_PE
#
# %%%% ProcessRNAseq.pl by Enrique Blanco @ CRG (2018)
#
# %%%% Stage 0.  Reading options [OK]
#
# %%%% Creating the info directory
# %%%% It is already existing
# %%%% Stage 1.  Mapping the RNAseq sample/s (/usr/local/molbio/01_raw_data/Wamstad/SRR900928_1.fastq.gz,/usr/local/molbio/01_raw_data/Wamstad/SRR900928_2.fastq.gz -> $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running tophat2 --zpacker pigz --transcriptome-index=$MOUSE10/transcriptome_index/refGene --no-coverage-search --mate-inner-dist 176 --mate-std-dev 11 -p 3 -g 1 -o $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE --library-type=fr-firststrand $MOUSE10/genome /usr/local/molbio/01_raw_data/Wamstad/SRR900928_1.fastq.gz /usr/local/molbio/01_raw_data/Wamstad/SRR900928_2.fastq.gz 2> info/tophat_RNA_ESC_2_Wamstad_2013_PE.txt [OK]
#
# %%%% Stage 2.  Obtaining the statistics ($MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running samtools flagstat $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits.bam > info/flagstat_RNA_ESC_2_Wamstad_2013_PE.txt%%%% Running cat info/flagstat_RNA_ESC_2_Wamstad_2013_PE.txt
# 42882019 + 0 in total (QC-passed reads + QC-failed reads)
# 42882019 + 0 primary
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 42882019 + 0 mapped (100.00% : N/A)
# 42882019 + 0 primary mapped (100.00% : N/A)
# 42882019 + 0 paired in sequencing
# 21505064 + 0 read1
# 21376955 + 0 read2
# 30682322 + 0 properly paired (71.55% : N/A)
# 41704510 + 0 with itself and mate mapped
# 1177509 + 0 singletons (2.75% : N/A)
# 2195944 + 0 with mate mapped to a different chr
# 2195944 + 0 with mate mapped to a different chr (mapQ>=5)
#  [OK]
#
# %%%% Stage 3.  Building the normalized profile/s for UCSC ($MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits.bam -> RNA_ESC_2_Wamstad_2013_PE)
# %%%% Running samtools view -h -o $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits.sam $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits.bam [OK]
#
# %%%% Running grep "XS:A:+" $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits_XSplus.sam [OK]
#
# %%%% Running grep "XS:A:-" $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits_XSminus.sam [OK]
#
# %%%% Running samtools view -H $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits.bam > $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/header.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits_XSplus.sam > $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits_XSplusH.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits_XSminus.sam > $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits_XSminusH.sam [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits_XSplusH.sam RNA_ESC_2_Wamstad_2013_PE_plus [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/accepted_hits_XSminusH.sam RNA_ESC_2_Wamstad_2013_PE_minus [OK]
#
# %%%% Running rm -f $MAPFILES/mm10/RNA_ESC_2_Wamstad_2013_PE/*.sam [OK]
#
# %%%% Successful termination:
# %%%% Total running time (hours): 0.737  hours
# %%%% Total running time (minutes): 44.25  mins
# %%%% Total running time (seconds): 2655  secs [OK]
#
# building file list ... done
# RNA_ESC_2_Wamstad_2013_PE/
# RNA_ESC_2_Wamstad_2013_PE/accepted_hits.bam
# RNA_ESC_2_Wamstad_2013_PE/align_summary.txt
# RNA_ESC_2_Wamstad_2013_PE/deletions.bed
# RNA_ESC_2_Wamstad_2013_PE/insertions.bed
# RNA_ESC_2_Wamstad_2013_PE/junctions.bed
# RNA_ESC_2_Wamstad_2013_PE/prep_reads.info
# RNA_ESC_2_Wamstad_2013_PE/unmapped.bam
# RNA_ESC_2_Wamstad_2013_PE/logs/
# RNA_ESC_2_Wamstad_2013_PE/logs/bam_merge_um.log
# RNA_ESC_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.log
# RNA_ESC_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um.log
# RNA_ESC_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um_unmapped.log
# RNA_ESC_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.log
# RNA_ESC_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um.log
# RNA_ESC_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um_unmapped.log
# RNA_ESC_2_Wamstad_2013_PE/logs/bowtie_build.log
# RNA_ESC_2_Wamstad_2013_PE/logs/gtf_juncs.log
# RNA_ESC_2_Wamstad_2013_PE/logs/juncs_db.log
# RNA_ESC_2_Wamstad_2013_PE/logs/long_spanning_reads.segs.log
# RNA_ESC_2_Wamstad_2013_PE/logs/m2g_left_kept_reads.err
# RNA_ESC_2_Wamstad_2013_PE/logs/m2g_left_kept_reads.out
# RNA_ESC_2_Wamstad_2013_PE/logs/m2g_right_kept_reads.err
# RNA_ESC_2_Wamstad_2013_PE/logs/m2g_right_kept_reads.out
# RNA_ESC_2_Wamstad_2013_PE/logs/prep_reads.log
# RNA_ESC_2_Wamstad_2013_PE/logs/reports.log
# RNA_ESC_2_Wamstad_2013_PE/logs/reports.merge_bam.log
# RNA_ESC_2_Wamstad_2013_PE/logs/reports.samtools_sort.log0
# RNA_ESC_2_Wamstad_2013_PE/logs/reports.samtools_sort.log1
# RNA_ESC_2_Wamstad_2013_PE/logs/reports.samtools_sort.log2
# RNA_ESC_2_Wamstad_2013_PE/logs/run.log
# RNA_ESC_2_Wamstad_2013_PE/logs/segment_juncs.log
# RNA_ESC_2_Wamstad_2013_PE/logs/tophat.log
#
# sent 1.38G bytes  received 714 bytes  212.67M bytes/sec
# total size is 1.38G  speedup is 1.00
#
# Index     = 2
# SRA       = SRR900929
# SAMPLE_ID = RNA_MES_1_Wamstad_2013_PE
# FQ_DIR    = /usr/local/molbio/01_raw_data/Wamstad/
# FQ1 = /usr/local/molbio/01_raw_data/Wamstad/SRR900929_1.fastq.gz
# FQ2 = /usr/local/molbio/01_raw_data/Wamstad/SRR900929_2.fastq.gz
# OUTDIR = /usr/local/molbio/02_map_files/mm10/RNA_MES_1_Wamstad_2013_PE
#
# %%%% ProcessRNAseq.pl by Enrique Blanco @ CRG (2018)
#
# %%%% Stage 0.  Reading options [OK]
#
# %%%% Creating the info directory
# %%%% It is already existing
# %%%% Stage 1.  Mapping the RNAseq sample/s (/usr/local/molbio/01_raw_data/Wamstad/SRR900929_1.fastq.gz,/usr/local/molbio/01_raw_data/Wamstad/SRR900929_2.fastq.gz -> $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running tophat2 --zpacker pigz --transcriptome-index=$MOUSE10/transcriptome_index/refGene --no-coverage-search --mate-inner-dist 176 --mate-std-dev 11 -p 3 -g 1 -o $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE --library-type=fr-firststrand $MOUSE10/genome /usr/local/molbio/01_raw_data/Wamstad/SRR900929_1.fastq.gz /usr/local/molbio/01_raw_data/Wamstad/SRR900929_2.fastq.gz 2> info/tophat_RNA_MES_1_Wamstad_2013_PE.txt [OK]
#
# %%%% Stage 2.  Obtaining the statistics ($MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running samtools flagstat $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits.bam > info/flagstat_RNA_MES_1_Wamstad_2013_PE.txt%%%% Running cat info/flagstat_RNA_MES_1_Wamstad_2013_PE.txt
# 40642659 + 0 in total (QC-passed reads + QC-failed reads)
# 40642659 + 0 primary
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 40642659 + 0 mapped (100.00% : N/A)
# 40642659 + 0 primary mapped (100.00% : N/A)
# 40642659 + 0 paired in sequencing
# 20470741 + 0 read1
# 20171918 + 0 read2
# 29090072 + 0 properly paired (71.58% : N/A)
# 39778854 + 0 with itself and mate mapped
# 863805 + 0 singletons (2.13% : N/A)
# 1274226 + 0 with mate mapped to a different chr
# 1274226 + 0 with mate mapped to a different chr (mapQ>=5)
#  [OK]
#
# %%%% Stage 3.  Building the normalized profile/s for UCSC ($MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits.bam -> RNA_MES_1_Wamstad_2013_PE)
# %%%% Running samtools view -h -o $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits.sam $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits.bam [OK]
#
# %%%% Running grep "XS:A:+" $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits_XSplus.sam [OK]
#
# %%%% Running grep "XS:A:-" $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits_XSminus.sam [OK]
#
# %%%% Running samtools view -H $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits.bam > $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/header.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits_XSplus.sam > $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits_XSplusH.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits_XSminus.sam > $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits_XSminusH.sam [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits_XSplusH.sam RNA_MES_1_Wamstad_2013_PE_plus [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/accepted_hits_XSminusH.sam RNA_MES_1_Wamstad_2013_PE_minus [OK]
#
# %%%% Running rm -f $MAPFILES/mm10/RNA_MES_1_Wamstad_2013_PE/*.sam [OK]
#
# %%%% Successful termination:
# %%%% Total running time (hours): 0.704  hours
# %%%% Total running time (minutes): 42.25  mins
# %%%% Total running time (seconds): 2535  secs [OK]
#
# building file list ... done
# RNA_MES_1_Wamstad_2013_PE/
# RNA_MES_1_Wamstad_2013_PE/accepted_hits.bam
# RNA_MES_1_Wamstad_2013_PE/align_summary.txt
# RNA_MES_1_Wamstad_2013_PE/deletions.bed
# RNA_MES_1_Wamstad_2013_PE/insertions.bed
# RNA_MES_1_Wamstad_2013_PE/junctions.bed
# RNA_MES_1_Wamstad_2013_PE/prep_reads.info
# RNA_MES_1_Wamstad_2013_PE/unmapped.bam
# RNA_MES_1_Wamstad_2013_PE/logs/
# RNA_MES_1_Wamstad_2013_PE/logs/bam_merge_um.log
# RNA_MES_1_Wamstad_2013_PE/logs/bowtie.left_kept_reads.log
# RNA_MES_1_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um.log
# RNA_MES_1_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um_unmapped.log
# RNA_MES_1_Wamstad_2013_PE/logs/bowtie.right_kept_reads.log
# RNA_MES_1_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um.log
# RNA_MES_1_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um_unmapped.log
# RNA_MES_1_Wamstad_2013_PE/logs/bowtie_build.log
# RNA_MES_1_Wamstad_2013_PE/logs/gtf_juncs.log
# RNA_MES_1_Wamstad_2013_PE/logs/juncs_db.log
# RNA_MES_1_Wamstad_2013_PE/logs/long_spanning_reads.segs.log
# RNA_MES_1_Wamstad_2013_PE/logs/m2g_left_kept_reads.err
# RNA_MES_1_Wamstad_2013_PE/logs/m2g_left_kept_reads.out
# RNA_MES_1_Wamstad_2013_PE/logs/m2g_right_kept_reads.err
# RNA_MES_1_Wamstad_2013_PE/logs/m2g_right_kept_reads.out
# RNA_MES_1_Wamstad_2013_PE/logs/prep_reads.log
# RNA_MES_1_Wamstad_2013_PE/logs/reports.log
# RNA_MES_1_Wamstad_2013_PE/logs/reports.merge_bam.log
# RNA_MES_1_Wamstad_2013_PE/logs/reports.samtools_sort.log0
# RNA_MES_1_Wamstad_2013_PE/logs/reports.samtools_sort.log1
# RNA_MES_1_Wamstad_2013_PE/logs/reports.samtools_sort.log2
# RNA_MES_1_Wamstad_2013_PE/logs/run.log
# RNA_MES_1_Wamstad_2013_PE/logs/segment_juncs.log
# RNA_MES_1_Wamstad_2013_PE/logs/tophat.log
#
# sent 1.27G bytes  received 714 bytes  231.80M bytes/sec
# total size is 1.27G  speedup is 1.00
#
# Index     = 3
# SRA       = SRR900930
# SAMPLE_ID = RNA_MES_2_Wamstad_2013_PE
# FQ_DIR    = /usr/local/molbio/01_raw_data/Wamstad/
# FQ1 = /usr/local/molbio/01_raw_data/Wamstad/SRR900930_1.fastq.gz
# FQ2 = /usr/local/molbio/01_raw_data/Wamstad/SRR900930_2.fastq.gz
# OUTDIR = /usr/local/molbio/02_map_files/mm10/RNA_MES_2_Wamstad_2013_PE
#
# %%%% ProcessRNAseq.pl by Enrique Blanco @ CRG (2018)
#
# %%%% Stage 0.  Reading options [OK]
#
# %%%% Creating the info directory
# %%%% It is already existing
# %%%% Stage 1.  Mapping the RNAseq sample/s (/usr/local/molbio/01_raw_data/Wamstad/SRR900930_1.fastq.gz,/usr/local/molbio/01_raw_data/Wamstad/SRR900930_2.fastq.gz -> $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running tophat2 --zpacker pigz --transcriptome-index=$MOUSE10/transcriptome_index/refGene --no-coverage-search --mate-inner-dist 176 --mate-std-dev 11 -p 3 -g 1 -o $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE --library-type=fr-firststrand $MOUSE10/genome /usr/local/molbio/01_raw_data/Wamstad/SRR900930_1.fastq.gz /usr/local/molbio/01_raw_data/Wamstad/SRR900930_2.fastq.gz 2> info/tophat_RNA_MES_2_Wamstad_2013_PE.txt [OK]
#
# %%%% Stage 2.  Obtaining the statistics ($MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running samtools flagstat $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits.bam > info/flagstat_RNA_MES_2_Wamstad_2013_PE.txt%%%% Running cat info/flagstat_RNA_MES_2_Wamstad_2013_PE.txt
# 39378171 + 0 in total (QC-passed reads + QC-failed reads)
# 39378171 + 0 primary
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 39378171 + 0 mapped (100.00% : N/A)
# 39378171 + 0 primary mapped (100.00% : N/A)
# 39378171 + 0 paired in sequencing
# 19807014 + 0 read1
# 19571157 + 0 read2
# 28528438 + 0 properly paired (72.45% : N/A)
# 38535112 + 0 with itself and mate mapped
# 843059 + 0 singletons (2.14% : N/A)
# 1398562 + 0 with mate mapped to a different chr
# 1398562 + 0 with mate mapped to a different chr (mapQ>=5)
#  [OK]
#
# %%%% Stage 3.  Building the normalized profile/s for UCSC ($MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits.bam -> RNA_MES_2_Wamstad_2013_PE)
# %%%% Running samtools view -h -o $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits.sam $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits.bam [OK]
#
# %%%% Running grep "XS:A:+" $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits_XSplus.sam [OK]
#
# %%%% Running grep "XS:A:-" $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits_XSminus.sam [OK]
#
# %%%% Running samtools view -H $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits.bam > $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/header.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits_XSplus.sam > $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits_XSplusH.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits_XSminus.sam > $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits_XSminusH.sam [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits_XSplusH.sam RNA_MES_2_Wamstad_2013_PE_plus [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/accepted_hits_XSminusH.sam RNA_MES_2_Wamstad_2013_PE_minus [OK]
#
# %%%% Running rm -f $MAPFILES/mm10/RNA_MES_2_Wamstad_2013_PE/*.sam [OK]
#
# %%%% Successful termination:
# %%%% Total running time (hours): 0.699  hours
# %%%% Total running time (minutes): 41.983  mins
# %%%% Total running time (seconds): 2519  secs [OK]
#
# building file list ... done
# RNA_MES_2_Wamstad_2013_PE/
# RNA_MES_2_Wamstad_2013_PE/accepted_hits.bam
# RNA_MES_2_Wamstad_2013_PE/align_summary.txt
# RNA_MES_2_Wamstad_2013_PE/deletions.bed
# RNA_MES_2_Wamstad_2013_PE/insertions.bed
# RNA_MES_2_Wamstad_2013_PE/junctions.bed
# RNA_MES_2_Wamstad_2013_PE/prep_reads.info
# RNA_MES_2_Wamstad_2013_PE/unmapped.bam
# RNA_MES_2_Wamstad_2013_PE/logs/
# RNA_MES_2_Wamstad_2013_PE/logs/bam_merge_um.log
# RNA_MES_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.log
# RNA_MES_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um.log
# RNA_MES_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um_unmapped.log
# RNA_MES_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.log
# RNA_MES_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um.log
# RNA_MES_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um_unmapped.log
# RNA_MES_2_Wamstad_2013_PE/logs/bowtie_build.log
# RNA_MES_2_Wamstad_2013_PE/logs/gtf_juncs.log
# RNA_MES_2_Wamstad_2013_PE/logs/juncs_db.log
# RNA_MES_2_Wamstad_2013_PE/logs/long_spanning_reads.segs.log
# RNA_MES_2_Wamstad_2013_PE/logs/m2g_left_kept_reads.err
# RNA_MES_2_Wamstad_2013_PE/logs/m2g_left_kept_reads.out
# RNA_MES_2_Wamstad_2013_PE/logs/m2g_right_kept_reads.err
# RNA_MES_2_Wamstad_2013_PE/logs/m2g_right_kept_reads.out
# RNA_MES_2_Wamstad_2013_PE/logs/prep_reads.log
# RNA_MES_2_Wamstad_2013_PE/logs/reports.log
# RNA_MES_2_Wamstad_2013_PE/logs/reports.merge_bam.log
# RNA_MES_2_Wamstad_2013_PE/logs/reports.samtools_sort.log0
# RNA_MES_2_Wamstad_2013_PE/logs/reports.samtools_sort.log1
# RNA_MES_2_Wamstad_2013_PE/logs/reports.samtools_sort.log2
# RNA_MES_2_Wamstad_2013_PE/logs/run.log
# RNA_MES_2_Wamstad_2013_PE/logs/segment_juncs.log
# RNA_MES_2_Wamstad_2013_PE/logs/tophat.log
#
# sent 1.25G bytes  received 714 bytes  226.79M bytes/sec
# total size is 1.25G  speedup is 1.00
#
# Index     = 4
# SRA       = SRR900931
# SAMPLE_ID = RNA_CP_1_Wamstad_2013_PE
# FQ_DIR    = /usr/local/molbio/01_raw_data/Wamstad/
# FQ1 = /usr/local/molbio/01_raw_data/Wamstad/SRR900931_1.fastq.gz
# FQ2 = /usr/local/molbio/01_raw_data/Wamstad/SRR900931_2.fastq.gz
# OUTDIR = /usr/local/molbio/02_map_files/mm10/RNA_CP_1_Wamstad_2013_PE
#
# %%%% ProcessRNAseq.pl by Enrique Blanco @ CRG (2018)
#
# %%%% Stage 0.  Reading options [OK]
#
# %%%% Creating the info directory
# %%%% It is already existing
# %%%% Stage 1.  Mapping the RNAseq sample/s (/usr/local/molbio/01_raw_data/Wamstad/SRR900931_1.fastq.gz,/usr/local/molbio/01_raw_data/Wamstad/SRR900931_2.fastq.gz -> $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running tophat2 --zpacker pigz --transcriptome-index=$MOUSE10/transcriptome_index/refGene --no-coverage-search --mate-inner-dist 176 --mate-std-dev 11 -p 3 -g 1 -o $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE --library-type=fr-firststrand $MOUSE10/genome /usr/local/molbio/01_raw_data/Wamstad/SRR900931_1.fastq.gz /usr/local/molbio/01_raw_data/Wamstad/SRR900931_2.fastq.gz 2> info/tophat_RNA_CP_1_Wamstad_2013_PE.txt [OK]
#
# %%%% Stage 2.  Obtaining the statistics ($MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running samtools flagstat $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits.bam > info/flagstat_RNA_CP_1_Wamstad_2013_PE.txt%%%% Running cat info/flagstat_RNA_CP_1_Wamstad_2013_PE.txt
# 41585604 + 0 in total (QC-passed reads + QC-failed reads)
# 41585604 + 0 primary
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 41585604 + 0 mapped (100.00% : N/A)
# 41585604 + 0 primary mapped (100.00% : N/A)
# 41585604 + 0 paired in sequencing
# 20921436 + 0 read1
# 20664168 + 0 read2
# 29423734 + 0 properly paired (70.75% : N/A)
# 40672510 + 0 with itself and mate mapped
# 913094 + 0 singletons (2.20% : N/A)
# 1460722 + 0 with mate mapped to a different chr
# 1460722 + 0 with mate mapped to a different chr (mapQ>=5)
#  [OK]
#
# %%%% Stage 3.  Building the normalized profile/s for UCSC ($MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits.bam -> RNA_CP_1_Wamstad_2013_PE)
# %%%% Running samtools view -h -o $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits.sam $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits.bam [OK]
#
# %%%% Running grep "XS:A:+" $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits_XSplus.sam [OK]
#
# %%%% Running grep "XS:A:-" $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits_XSminus.sam [OK]
#
# %%%% Running samtools view -H $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits.bam > $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/header.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits_XSplus.sam > $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits_XSplusH.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits_XSminus.sam > $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits_XSminusH.sam [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits_XSplusH.sam RNA_CP_1_Wamstad_2013_PE_plus [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/accepted_hits_XSminusH.sam RNA_CP_1_Wamstad_2013_PE_minus [OK]
#
# %%%% Running rm -f $MAPFILES/mm10/RNA_CP_1_Wamstad_2013_PE/*.sam [OK]
#
# %%%% Successful termination:
# %%%% Total running time (hours): 0.74  hours
# %%%% Total running time (minutes): 44.4  mins
# %%%% Total running time (seconds): 2664  secs [OK]
#
# building file list ... done
# RNA_CP_1_Wamstad_2013_PE/
# RNA_CP_1_Wamstad_2013_PE/accepted_hits.bam
# RNA_CP_1_Wamstad_2013_PE/align_summary.txt
# RNA_CP_1_Wamstad_2013_PE/deletions.bed
# RNA_CP_1_Wamstad_2013_PE/insertions.bed
# RNA_CP_1_Wamstad_2013_PE/junctions.bed
# RNA_CP_1_Wamstad_2013_PE/prep_reads.info
# RNA_CP_1_Wamstad_2013_PE/unmapped.bam
# RNA_CP_1_Wamstad_2013_PE/logs/
# RNA_CP_1_Wamstad_2013_PE/logs/bam_merge_um.log
# RNA_CP_1_Wamstad_2013_PE/logs/bowtie.left_kept_reads.log
# RNA_CP_1_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um.log
# RNA_CP_1_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um_unmapped.log
# RNA_CP_1_Wamstad_2013_PE/logs/bowtie.right_kept_reads.log
# RNA_CP_1_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um.log
# RNA_CP_1_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um_unmapped.log
# RNA_CP_1_Wamstad_2013_PE/logs/bowtie_build.log
# RNA_CP_1_Wamstad_2013_PE/logs/gtf_juncs.log
# RNA_CP_1_Wamstad_2013_PE/logs/juncs_db.log
# RNA_CP_1_Wamstad_2013_PE/logs/long_spanning_reads.segs.log
# RNA_CP_1_Wamstad_2013_PE/logs/m2g_left_kept_reads.err
# RNA_CP_1_Wamstad_2013_PE/logs/m2g_left_kept_reads.out
# RNA_CP_1_Wamstad_2013_PE/logs/m2g_right_kept_reads.err
# RNA_CP_1_Wamstad_2013_PE/logs/m2g_right_kept_reads.out
# RNA_CP_1_Wamstad_2013_PE/logs/prep_reads.log
# RNA_CP_1_Wamstad_2013_PE/logs/reports.log
# RNA_CP_1_Wamstad_2013_PE/logs/reports.merge_bam.log
# RNA_CP_1_Wamstad_2013_PE/logs/reports.samtools_sort.log0
# RNA_CP_1_Wamstad_2013_PE/logs/reports.samtools_sort.log1
# RNA_CP_1_Wamstad_2013_PE/logs/reports.samtools_sort.log2
# RNA_CP_1_Wamstad_2013_PE/logs/run.log
# RNA_CP_1_Wamstad_2013_PE/logs/segment_juncs.log
# RNA_CP_1_Wamstad_2013_PE/logs/tophat.log
#
# sent 1.34G bytes  received 714 bytes  206.68M bytes/sec
# total size is 1.34G  speedup is 1.00
#
# Index     = 5
# SRA       = SRR900932
# SAMPLE_ID = RNA_CP_2_Wamstad_2013_PE
# FQ_DIR    = /usr/local/molbio/01_raw_data/Wamstad/
# FQ1 = /usr/local/molbio/01_raw_data/Wamstad/SRR900932_1.fastq.gz
# FQ2 = /usr/local/molbio/01_raw_data/Wamstad/SRR900932_2.fastq.gz
# OUTDIR = /usr/local/molbio/02_map_files/mm10/RNA_CP_2_Wamstad_2013_PE
#
# %%%% ProcessRNAseq.pl by Enrique Blanco @ CRG (2018)
#
# %%%% Stage 0.  Reading options [OK]
#
# %%%% Creating the info directory
# %%%% It is already existing
# %%%% Stage 1.  Mapping the RNAseq sample/s (/usr/local/molbio/01_raw_data/Wamstad/SRR900932_1.fastq.gz,/usr/local/molbio/01_raw_data/Wamstad/SRR900932_2.fastq.gz -> $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running tophat2 --zpacker pigz --transcriptome-index=$MOUSE10/transcriptome_index/refGene --no-coverage-search --mate-inner-dist 176 --mate-std-dev 11 -p 3 -g 1 -o $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE --library-type=fr-firststrand $MOUSE10/genome /usr/local/molbio/01_raw_data/Wamstad/SRR900932_1.fastq.gz /usr/local/molbio/01_raw_data/Wamstad/SRR900932_2.fastq.gz 2> info/tophat_RNA_CP_2_Wamstad_2013_PE.txt [OK]
#
# %%%% Stage 2.  Obtaining the statistics ($MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running samtools flagstat $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits.bam > info/flagstat_RNA_CP_2_Wamstad_2013_PE.txt%%%% Running cat info/flagstat_RNA_CP_2_Wamstad_2013_PE.txt
# 40731481 + 0 in total (QC-passed reads + QC-failed reads)
# 40731481 + 0 primary
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 40731481 + 0 mapped (100.00% : N/A)
# 40731481 + 0 primary mapped (100.00% : N/A)
# 40731481 + 0 paired in sequencing
# 20473358 + 0 read1
# 20258123 + 0 read2
# 28663514 + 0 properly paired (70.37% : N/A)
# 39902200 + 0 with itself and mate mapped
# 829281 + 0 singletons (2.04% : N/A)
# 1337610 + 0 with mate mapped to a different chr
# 1337610 + 0 with mate mapped to a different chr (mapQ>=5)
#  [OK]
#
# %%%% Stage 3.  Building the normalized profile/s for UCSC ($MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits.bam -> RNA_CP_2_Wamstad_2013_PE)
# %%%% Running samtools view -h -o $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits.sam $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits.bam [OK]
#
# %%%% Running grep "XS:A:+" $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits_XSplus.sam [OK]
#
# %%%% Running grep "XS:A:-" $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits_XSminus.sam [OK]
#
# %%%% Running samtools view -H $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits.bam > $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/header.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits_XSplus.sam > $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits_XSplusH.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits_XSminus.sam > $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits_XSminusH.sam [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits_XSplusH.sam RNA_CP_2_Wamstad_2013_PE_plus [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/accepted_hits_XSminusH.sam RNA_CP_2_Wamstad_2013_PE_minus [OK]
#
# %%%% Running rm -f $MAPFILES/mm10/RNA_CP_2_Wamstad_2013_PE/*.sam [OK]
#
# %%%% Successful termination:
# %%%% Total running time (hours): 0.726  hours
# %%%% Total running time (minutes): 43.566  mins
# %%%% Total running time (seconds): 2614  secs [OK]
#
# building file list ... done
# RNA_CP_2_Wamstad_2013_PE/
# RNA_CP_2_Wamstad_2013_PE/accepted_hits.bam
# RNA_CP_2_Wamstad_2013_PE/align_summary.txt
# RNA_CP_2_Wamstad_2013_PE/deletions.bed
# RNA_CP_2_Wamstad_2013_PE/insertions.bed
# RNA_CP_2_Wamstad_2013_PE/junctions.bed
# RNA_CP_2_Wamstad_2013_PE/prep_reads.info
# RNA_CP_2_Wamstad_2013_PE/unmapped.bam
# RNA_CP_2_Wamstad_2013_PE/logs/
# RNA_CP_2_Wamstad_2013_PE/logs/bam_merge_um.log
# RNA_CP_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.log
# RNA_CP_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um.log
# RNA_CP_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um_unmapped.log
# RNA_CP_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.log
# RNA_CP_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um.log
# RNA_CP_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um_unmapped.log
# RNA_CP_2_Wamstad_2013_PE/logs/bowtie_build.log
# RNA_CP_2_Wamstad_2013_PE/logs/gtf_juncs.log
# RNA_CP_2_Wamstad_2013_PE/logs/juncs_db.log
# RNA_CP_2_Wamstad_2013_PE/logs/long_spanning_reads.segs.log
# RNA_CP_2_Wamstad_2013_PE/logs/m2g_left_kept_reads.err
# RNA_CP_2_Wamstad_2013_PE/logs/m2g_left_kept_reads.out
# RNA_CP_2_Wamstad_2013_PE/logs/m2g_right_kept_reads.err
# RNA_CP_2_Wamstad_2013_PE/logs/m2g_right_kept_reads.out
# RNA_CP_2_Wamstad_2013_PE/logs/prep_reads.log
# RNA_CP_2_Wamstad_2013_PE/logs/reports.log
# RNA_CP_2_Wamstad_2013_PE/logs/reports.merge_bam.log
# RNA_CP_2_Wamstad_2013_PE/logs/reports.samtools_sort.log0
# RNA_CP_2_Wamstad_2013_PE/logs/reports.samtools_sort.log1
# RNA_CP_2_Wamstad_2013_PE/logs/reports.samtools_sort.log2
# RNA_CP_2_Wamstad_2013_PE/logs/run.log
# RNA_CP_2_Wamstad_2013_PE/logs/segment_juncs.log
# RNA_CP_2_Wamstad_2013_PE/logs/tophat.log
#
# sent 1.30G bytes  received 714 bytes  200.39M bytes/sec
# total size is 1.30G  speedup is 1.00
#
# Index     = 6
# SRA       = SRR900933
# SAMPLE_ID = RNA_CM_1_Wamstad_2013_PE
# FQ_DIR    = /usr/local/molbio/01_raw_data/Wamstad/
# FQ1 = /usr/local/molbio/01_raw_data/Wamstad/SRR900933_1.fastq.gz
# FQ2 = /usr/local/molbio/01_raw_data/Wamstad/SRR900933_2.fastq.gz
# OUTDIR = /usr/local/molbio/02_map_files/mm10/RNA_CM_1_Wamstad_2013_PE
#
# %%%% ProcessRNAseq.pl by Enrique Blanco @ CRG (2018)
#
# %%%% Stage 0.  Reading options [OK]
#
# %%%% Creating the info directory
# %%%% It is already existing
# %%%% Stage 1.  Mapping the RNAseq sample/s (/usr/local/molbio/01_raw_data/Wamstad/SRR900933_1.fastq.gz,/usr/local/molbio/01_raw_data/Wamstad/SRR900933_2.fastq.gz -> $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running tophat2 --zpacker pigz --transcriptome-index=$MOUSE10/transcriptome_index/refGene --no-coverage-search --mate-inner-dist 176 --mate-std-dev 11 -p 3 -g 1 -o $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE --library-type=fr-firststrand $MOUSE10/genome /usr/local/molbio/01_raw_data/Wamstad/SRR900933_1.fastq.gz /usr/local/molbio/01_raw_data/Wamstad/SRR900933_2.fastq.gz 2> info/tophat_RNA_CM_1_Wamstad_2013_PE.txt [OK]
#
# %%%% Stage 2.  Obtaining the statistics ($MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running samtools flagstat $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits.bam > info/flagstat_RNA_CM_1_Wamstad_2013_PE.txt%%%% Running cat info/flagstat_RNA_CM_1_Wamstad_2013_PE.txt
# 57779285 + 0 in total (QC-passed reads + QC-failed reads)
# 57779285 + 0 primary
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 57779285 + 0 mapped (100.00% : N/A)
# 57779285 + 0 primary mapped (100.00% : N/A)
# 57779285 + 0 paired in sequencing
# 28999838 + 0 read1
# 28779447 + 0 read2
# 44942906 + 0 properly paired (77.78% : N/A)
# 56712564 + 0 with itself and mate mapped
# 1066721 + 0 singletons (1.85% : N/A)
# 1710366 + 0 with mate mapped to a different chr
# 1710366 + 0 with mate mapped to a different chr (mapQ>=5)
#  [OK]
#
# %%%% Stage 3.  Building the normalized profile/s for UCSC ($MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits.bam -> RNA_CM_1_Wamstad_2013_PE)
# %%%% Running samtools view -h -o $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits.sam $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits.bam [OK]
#
# %%%% Running grep "XS:A:+" $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits_XSplus.sam [OK]
#
# %%%% Running grep "XS:A:-" $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits_XSminus.sam [OK]
#
# %%%% Running samtools view -H $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits.bam > $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/header.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits_XSplus.sam > $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits_XSplusH.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits_XSminus.sam > $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits_XSminusH.sam [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits_XSplusH.sam RNA_CM_1_Wamstad_2013_PE_plus [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/accepted_hits_XSminusH.sam RNA_CM_1_Wamstad_2013_PE_minus [OK]
#
# %%%% Running rm -f $MAPFILES/mm10/RNA_CM_1_Wamstad_2013_PE/*.sam [OK]
#
# %%%% Successful termination:
# %%%% Total running time (hours): 0.934  hours
# %%%% Total running time (minutes): 56.083  mins
# %%%% Total running time (seconds): 3365  secs [OK]
#
# building file list ... done
# RNA_CM_1_Wamstad_2013_PE/
# RNA_CM_1_Wamstad_2013_PE/accepted_hits.bam
# RNA_CM_1_Wamstad_2013_PE/align_summary.txt
# RNA_CM_1_Wamstad_2013_PE/deletions.bed
# RNA_CM_1_Wamstad_2013_PE/insertions.bed
# RNA_CM_1_Wamstad_2013_PE/junctions.bed
# RNA_CM_1_Wamstad_2013_PE/prep_reads.info
# RNA_CM_1_Wamstad_2013_PE/unmapped.bam
# RNA_CM_1_Wamstad_2013_PE/logs/
# RNA_CM_1_Wamstad_2013_PE/logs/bam_merge_um.log
# RNA_CM_1_Wamstad_2013_PE/logs/bowtie.left_kept_reads.log
# RNA_CM_1_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um.log
# RNA_CM_1_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um_unmapped.log
# RNA_CM_1_Wamstad_2013_PE/logs/bowtie.right_kept_reads.log
# RNA_CM_1_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um.log
# RNA_CM_1_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um_unmapped.log
# RNA_CM_1_Wamstad_2013_PE/logs/bowtie_build.log
# RNA_CM_1_Wamstad_2013_PE/logs/gtf_juncs.log
# RNA_CM_1_Wamstad_2013_PE/logs/juncs_db.log
# RNA_CM_1_Wamstad_2013_PE/logs/long_spanning_reads.segs.log
# RNA_CM_1_Wamstad_2013_PE/logs/m2g_left_kept_reads.err
# RNA_CM_1_Wamstad_2013_PE/logs/m2g_left_kept_reads.out
# RNA_CM_1_Wamstad_2013_PE/logs/m2g_right_kept_reads.err
# RNA_CM_1_Wamstad_2013_PE/logs/m2g_right_kept_reads.out
# RNA_CM_1_Wamstad_2013_PE/logs/prep_reads.log
# RNA_CM_1_Wamstad_2013_PE/logs/reports.log
# RNA_CM_1_Wamstad_2013_PE/logs/reports.merge_bam.log
# RNA_CM_1_Wamstad_2013_PE/logs/reports.samtools_sort.log0
# RNA_CM_1_Wamstad_2013_PE/logs/reports.samtools_sort.log1
# RNA_CM_1_Wamstad_2013_PE/logs/reports.samtools_sort.log2
# RNA_CM_1_Wamstad_2013_PE/logs/run.log
# RNA_CM_1_Wamstad_2013_PE/logs/segment_juncs.log
# RNA_CM_1_Wamstad_2013_PE/logs/tophat.log
#
# sent 1.73G bytes  received 714 bytes  203.09M bytes/sec
# total size is 1.73G  speedup is 1.00
#
# Index     = 7
# SRA       = SRR900934
# SAMPLE_ID = RNA_CM_2_Wamstad_2013_PE
# FQ_DIR    = /usr/local/molbio/01_raw_data/Wamstad/
# FQ1 = /usr/local/molbio/01_raw_data/Wamstad/SRR900934_1.fastq.gz
# FQ2 = /usr/local/molbio/01_raw_data/Wamstad/SRR900934_2.fastq.gz
# OUTDIR = /usr/local/molbio/02_map_files/mm10/RNA_CM_2_Wamstad_2013_PE
#
# %%%% ProcessRNAseq.pl by Enrique Blanco @ CRG (2018)
#
# %%%% Stage 0.  Reading options [OK]
#
# %%%% Creating the info directory
# %%%% It is already existing
# %%%% Stage 1.  Mapping the RNAseq sample/s (/usr/local/molbio/01_raw_data/Wamstad/SRR900934_1.fastq.gz,/usr/local/molbio/01_raw_data/Wamstad/SRR900934_2.fastq.gz -> $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running tophat2 --zpacker pigz --transcriptome-index=$MOUSE10/transcriptome_index/refGene --no-coverage-search --mate-inner-dist 176 --mate-std-dev 11 -p 3 -g 1 -o $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE --library-type=fr-firststrand $MOUSE10/genome /usr/local/molbio/01_raw_data/Wamstad/SRR900934_1.fastq.gz /usr/local/molbio/01_raw_data/Wamstad/SRR900934_2.fastq.gz 2> info/tophat_RNA_CM_2_Wamstad_2013_PE.txt [OK]
#
# %%%% Stage 2.  Obtaining the statistics ($MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits.bam)
# %%%% Running samtools flagstat $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits.bam > info/flagstat_RNA_CM_2_Wamstad_2013_PE.txt%%%% Running cat info/flagstat_RNA_CM_2_Wamstad_2013_PE.txt
# 55013670 + 0 in total (QC-passed reads + QC-failed reads)
# 55013670 + 0 primary
# 0 + 0 secondary
# 0 + 0 supplementary
# 0 + 0 duplicates
# 0 + 0 primary duplicates
# 55013670 + 0 mapped (100.00% : N/A)
# 55013670 + 0 primary mapped (100.00% : N/A)
# 55013670 + 0 paired in sequencing
# 27571852 + 0 read1
# 27441818 + 0 read2
# 40261700 + 0 properly paired (73.18% : N/A)
# 53833448 + 0 with itself and mate mapped
# 1180222 + 0 singletons (2.15% : N/A)
# 1841430 + 0 with mate mapped to a different chr
# 1841430 + 0 with mate mapped to a different chr (mapQ>=5)
#  [OK]
#
# %%%% Stage 3.  Building the normalized profile/s for UCSC ($MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits.bam -> RNA_CM_2_Wamstad_2013_PE)
# %%%% Running samtools view -h -o $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits.sam $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits.bam [OK]
#
# %%%% Running grep "XS:A:+" $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits_XSplus.sam [OK]
#
# %%%% Running grep "XS:A:-" $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits.sam > $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits_XSminus.sam [OK]
#
# %%%% Running samtools view -H $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits.bam > $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/header.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits_XSplus.sam > $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits_XSplusH.sam [OK]
#
# %%%% Running cat $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/header.sam $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits_XSminus.sam > $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits_XSminusH.sam [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits_XSplusH.sam RNA_CM_2_Wamstad_2013_PE_plus [OK]
#
# %%%% Running buildChIPprofile -p $MOUSE10/ChromInfo.txt $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/accepted_hits_XSminusH.sam RNA_CM_2_Wamstad_2013_PE_minus [OK]
#
# %%%% Running rm -f $MAPFILES/mm10/RNA_CM_2_Wamstad_2013_PE/*.sam [OK]
#
# %%%% Successful termination:
# %%%% Total running time (hours): 0.897  hours
# %%%% Total running time (minutes): 53.866  mins
# %%%% Total running time (seconds): 3232  secs [OK]
#
# building file list ... done
# RNA_CM_2_Wamstad_2013_PE/
# RNA_CM_2_Wamstad_2013_PE/accepted_hits.bam
# RNA_CM_2_Wamstad_2013_PE/align_summary.txt
# RNA_CM_2_Wamstad_2013_PE/deletions.bed
# RNA_CM_2_Wamstad_2013_PE/insertions.bed
# RNA_CM_2_Wamstad_2013_PE/junctions.bed
# RNA_CM_2_Wamstad_2013_PE/prep_reads.info
# RNA_CM_2_Wamstad_2013_PE/unmapped.bam
# RNA_CM_2_Wamstad_2013_PE/logs/
# RNA_CM_2_Wamstad_2013_PE/logs/bam_merge_um.log
# RNA_CM_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.log
# RNA_CM_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um.log
# RNA_CM_2_Wamstad_2013_PE/logs/bowtie.left_kept_reads.m2g_um_unmapped.log
# RNA_CM_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.log
# RNA_CM_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um.log
# RNA_CM_2_Wamstad_2013_PE/logs/bowtie.right_kept_reads.m2g_um_unmapped.log
# RNA_CM_2_Wamstad_2013_PE/logs/bowtie_build.log
# RNA_CM_2_Wamstad_2013_PE/logs/gtf_juncs.log
# RNA_CM_2_Wamstad_2013_PE/logs/juncs_db.log
# RNA_CM_2_Wamstad_2013_PE/logs/long_spanning_reads.segs.log
# RNA_CM_2_Wamstad_2013_PE/logs/m2g_left_kept_reads.err
# RNA_CM_2_Wamstad_2013_PE/logs/m2g_left_kept_reads.out
# RNA_CM_2_Wamstad_2013_PE/logs/m2g_right_kept_reads.err
# RNA_CM_2_Wamstad_2013_PE/logs/m2g_right_kept_reads.out
# RNA_CM_2_Wamstad_2013_PE/logs/prep_reads.log
# RNA_CM_2_Wamstad_2013_PE/logs/reports.log
# RNA_CM_2_Wamstad_2013_PE/logs/reports.merge_bam.log
# RNA_CM_2_Wamstad_2013_PE/logs/reports.samtools_sort.log0
# RNA_CM_2_Wamstad_2013_PE/logs/reports.samtools_sort.log1
# RNA_CM_2_Wamstad_2013_PE/logs/reports.samtools_sort.log2
# RNA_CM_2_Wamstad_2013_PE/logs/run.log
# RNA_CM_2_Wamstad_2013_PE/logs/segment_juncs.log
# RNA_CM_2_Wamstad_2013_PE/logs/tophat.log
#
# sent 1.70G bytes  received 714 bytes  200.09M bytes/sec
# total size is 1.70G  speedup is 1.00
# CPU times: user 1min 19s, sys: 24.9 s, total: 1min 44s
# Wall time: 5h 27min 12s

# %% [markdown]
# ### Assert all the SAMPLE IDs have a BAM file

# %%
import os
SAMPLE_IDS = pd.Index([sample_id  for sample_id in RNA_TABLE['SAMPLE_ID']])
BAMS = pd.Index(os.listdir(SSD_DIR))
assert len(SAMPLE_IDS.intersection(BAMS)) == len(SAMPLE_IDS)

# %%
SAMPLE_IDS.intersection(BAMS)
# Out:
# Index(['RNA_ESC_1_Wamstad_2013_PE', 'RNA_ESC_2_Wamstad_2013_PE',
#        'RNA_MES_1_Wamstad_2013_PE', 'RNA_MES_2_Wamstad_2013_PE',
#        'RNA_CP_1_Wamstad_2013_PE', 'RNA_CP_2_Wamstad_2013_PE',
#        'RNA_CM_1_Wamstad_2013_PE', 'RNA_CM_2_Wamstad_2013_PE'],
#       dtype='object')
